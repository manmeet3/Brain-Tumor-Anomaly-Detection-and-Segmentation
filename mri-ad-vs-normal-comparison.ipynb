# %% [markdown]
# Visually see the difference between an alzheimer's scan and a normal scan
# - Certain areas to be highlighted: hippocampus
# - Pay attention to general volume of gray matter to skull ratio
# - Do analysis on color distributions

# %% [markdown]
# AD: sub-OAS30031_ses-d0427_run-01_T1w.nii.gz, sub-OAS30031_ses-d0427_run-02_T1w.nii.gz
#
# Normal: sub-OAS30001_ses-d0757_run-01_T1w.nii.gz, sub-OAS30001_ses-d0757_run-02_T1w.nii.gz

# %%
# !pip install nibabel
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 3.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import nibabel as nib
import os

# %%
# !ls /tmp/data/labeled/ad
# Out:
# sub-OAS30016_ses-d0021_T1w.nii.gz
# sub-OAS30024_ses-d0084_T1w.nii.gz
# sub-OAS30029_ses-d0893_T1w.nii.gz
# sub-OAS30031_ses-d0427_run-01_T1w.nii.gz
# sub-OAS30031_ses-d0427_run-02_T1w.nii.gz
# sub-OAS30051_ses-d1286_T1w.nii.gz
# sub-OAS30056_ses-d3491_T1w.nii.gz
# sub-OAS30058_ses-d1316_run-01_T1w.nii.gz
# sub-OAS30058_ses-d1316_run-02_T1w.nii.gz
# sub-OAS30058_ses-d2236_T1w.nii.gz
# sub-OAS30064_ses-d0687_run-01_T1w.nii.gz
# sub-OAS30064_ses-d0687_run-02_T1w.nii.gz
# sub-OAS30068_ses-d0076_T1w.nii.gz
# sub-OAS30070_ses-d0070_T1w.nii.gz
# sub-OAS30072_ses-d2219_T1w.nii.gz
# sub-OAS30085_ses-d1566_T1w.nii.gz
# sub-OAS30091_ses-d0092_run-01_T1w.nii.gz
# sub-OAS30091_ses-d0092_run-02_T1w.nii.gz
# sub-OAS30095_ses-d0033_T1w.nii.gz
# sub-OAS30098_ses-d0036_T1w.nii.gz
# sub-OAS30111_ses-d0385_run-01_T1w.nii.gz
# sub-OAS30111_ses-d0385_run-02_T1w.nii.gz
# sub-OAS30114_ses-d0086_T1w.nii.gz
# sub-OAS30116_ses-d0017_run-01_T1w.nii.gz
# sub-OAS30116_ses-d0017_run-02_T1w.nii.gz
# ...

# %%
# !ls /tmp/data/labeled/normal
# Out:
# sub-OAS30001_ses-d0757_run-01_T1w.nii.gz
# sub-OAS30001_ses-d0757_run-02_T1w.nii.gz
# sub-OAS30002_ses-d0653_run-01_T1w.nii.gz
# sub-OAS30002_ses-d0653_run-02_T1w.nii.gz
# sub-OAS30002_ses-d2345_T1w.nii.gz
# sub-OAS30003_ses-d2682_T1w.nii.gz
# sub-OAS30003_ses-d3320_T1w.nii.gz
# sub-OAS30003_ses-d3731_T1w.nii.gz
# sub-OAS30004_ses-d1101_run-01_T1w.nii.gz
# sub-OAS30004_ses-d1101_run-02_T1w.nii.gz
# sub-OAS30004_ses-d2232_run-01_T1w.nii.gz
# sub-OAS30004_ses-d2232_run-02_T1w.nii.gz
# sub-OAS30004_ses-d3457_T1w.nii.gz
# sub-OAS30005_ses-d1274_run-01_T1w.nii.gz
# sub-OAS30005_ses-d1274_run-02_T1w.nii.gz
# sub-OAS30005_ses-d2384_T1w.nii.gz
# sub-OAS30006_ses-d2342_T1w.nii.gz
# sub-OAS30006_ses-d3386_T1w.nii.gz
# sub-OAS30007_ses-d0061_run-01_T1w.nii.gz
# sub-OAS30007_ses-d0061_run-02_T1w.nii.gz
# sub-OAS30007_ses-d1641_T1w.nii.gz
# sub-OAS30007_ses-d1981_T1w.nii.gz
# sub-OAS30008_ses-d0061_run-01_T1w.nii.gz
# sub-OAS30008_ses-d0061_run-02_T1w.nii.gz
# sub-OAS30009_ses-d2457_T1w.nii.gz
# ...

# %%
ad_1 = nib.load(os.path.join('/tmp/data/labeled/ad/sub-OAS30031_ses-d0427_run-01_T1w.nii.gz'))
ad_2 = nib.load(os.path.join('/tmp/data/labeled/ad/sub-OAS30031_ses-d0427_run-02_T1w.nii.gz'))

# %%
ad_1.shape
# Out:
# (176, 256, 256)

# %%
ad_2.shape
# Out:
# (176, 256, 256)

# %%
#scan = nib.load(os.path.join('/tmp/data/labeled/ad/sub-OAS31171_ses-d0752_T1w.nii.gz'))
#scan.shape
# Out:
# (176, 256, 256)

# %%
dir(ad_1)
# Out:
# ['ImageArrayProxy',
#  'ImageSlicer',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_affine',
#  '_affine2header',
#  '_compressed_suffixes',
#  '_data',
#  '_data_cache',
#  '_dataobj',
#  '_fdata_cache',
#  '_get_fileholders',
#  '_header',
#  '_load_cache',
#  '_meta_sniff_len',
#  '_sniff_meta_for',
#  'affine',
#  'as_reoriented',
#  'dataobj',
#  'extra',
#  'file_map',
#  'files_types',
#  'filespec_to_file_map',
#  'filespec_to_files',
#  'from_bytes',
#  'from_file_map',
#  'from_filename',
#  'from_files',
#  'from_image',
#  'get_affine',
#  'get_data',
#  'get_data_dtype',
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.imshow(ad_1.get_fdata()[:,:,135])

# %%
data = ad_1.get_fdata()

# %%
data.shape
# Out:
# (176, 256, 256)

# %%
fig=plt.figure(figsize=(80,150))
columns = 10
rows = 26
for i in range(1, len(data[0][0])):
    img = data[:,:,i]
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
